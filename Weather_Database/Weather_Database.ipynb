# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from datetime import datetime

# add sys.path to config.py module
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_url= url + "&q=" + "Boston"
city_weather= requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 57.74,
#   'feels_like': 55.76,
#   'temp_min': 52.95,
#   'temp_max': 64.8,
#   'pressure': 1019,
#   'humidity': 54},
#  'visibility': 10000,
#  'wind': {'speed': 3, 'deg': 138, 'gust': 11.01},
#  'clouds': {'all': 90},
#  'dt': 1622221906,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1622193133,
#   'sunset': 1622247074},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_cond = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_cond,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nago
# Processing Record 2 of Set 1 | awjilah
# Processing Record 3 of Set 1 | segezha
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | kodiak
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | buala
# Processing Record 14 of Set 1 | arraial do cabo
# Processing Record 15 of Set 1 | mahebourg
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | vilhena
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | saryg-sep
# Processing Record 25 of Set 1 | moba
# Processing Record 26 of Set 1 | tezu
# Processing Record 27 of Set 1 | bambanglipuro
# Processing Record 28 of Set 1 | areia branca
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | kaniama
# Processing Record 31 of Set 1 | constitucion
# Processing Record 32 of Set 1 | seredka
# Processing Record 33 of Set 1 | basco
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | gemena
# Processing Record 36 of Set 1 | la ronge
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | avera
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | souillac
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | moquegua
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | moron
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | nuuk
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | paso de los toros
# Processing Record 1 of Set 2 | frontera
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | hasaki
# Processing Record 4 of Set 2 | cayenne
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | daoukro
# Processing Record 11 of Set 2 | pevek
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | qui nhon
# Processing Record 14 of Set 2 | sangmelima
# Processing Record 15 of Set 2 | bathsheba
# Processing Record 16 of Set 2 | san cristobal
# Processing Record 17 of Set 2 | talnakh
# Processing Record 18 of Set 2 | nizhnyaya poyma
# Processing Record 19 of Set 2 | pacific grove
# Processing Record 20 of Set 2 | batemans bay
# Processing Record 21 of Set 2 | ketchikan
# Processing Record 22 of Set 2 | vagur
# Processing Record 23 of Set 2 | uyuni
# Processing Record 24 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 2 | luderitz
# Processing Record 26 of Set 2 | saint george
# Processing Record 27 of Set 2 | cherskiy
# Processing Record 28 of Set 2 | ardakan
# Processing Record 29 of Set 2 | mehamn
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | kruisfontein
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | vyartsilya
# Processing Record 34 of Set 2 | kavieng
# Processing Record 35 of Set 2 | kangaatsiaq
# Processing Record 36 of Set 2 | semey
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | bandarbeyla
# Processing Record 39 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 2 | hermanus
# Processing Record 41 of Set 2 | marawi
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | caucaia
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | huangpu
# Processing Record 46 of Set 2 | boulsa
# Processing Record 47 of Set 2 | montrose
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | carnarvon
# Processing Record 50 of Set 2 | fairbanks
# Processing Record 1 of Set 3 | acarau
# Processing Record 2 of Set 3 | lota
# Processing Record 3 of Set 3 | guadalupe y calvo
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | hovd
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | saint anthony
# Processing Record 8 of Set 3 | paratinga
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | namwala
# Processing Record 11 of Set 3 | port alfred
# Processing Record 12 of Set 3 | otradnoye
# Processing Record 13 of Set 3 | lompoc
# Processing Record 14 of Set 3 | chumikan
# Processing Record 15 of Set 3 | preeceville
# Processing Record 16 of Set 3 | bubaque
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | bara
# Processing Record 19 of Set 3 | ziro
# Processing Record 20 of Set 3 | chilliwack
# Processing Record 21 of Set 3 | haines junction
# Processing Record 22 of Set 3 | malakal
# Processing Record 23 of Set 3 | coahuayana
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | sabang
# Processing Record 26 of Set 3 | bulgan
# Processing Record 27 of Set 3 | japura
# Processing Record 28 of Set 3 | padang
# Processing Record 29 of Set 3 | berdavan
# Processing Record 30 of Set 3 | garachine
# Processing Record 31 of Set 3 | sibiti
# Processing Record 32 of Set 3 | yumen
# Processing Record 33 of Set 3 | inhambane
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 36 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 3 | ahipara
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | mayor pablo lagerenza
# Processing Record 40 of Set 3 | tucuman
# Processing Record 41 of Set 3 | zwedru
# Processing Record 42 of Set 3 | constantine
# Processing Record 43 of Set 3 | villa bruzual
# Processing Record 44 of Set 3 | san vicente
# Processing Record 45 of Set 3 | nobres
# Processing Record 46 of Set 3 | tateyama
# Processing Record 47 of Set 3 | ola
# Processing Record 48 of Set 3 | biloela
# Processing Record 49 of Set 3 | parral
# Processing Record 50 of Set 3 | oktyabrskiy
# Processing Record 1 of Set 4 | beloha
# Processing Record 2 of Set 4 | mount isa
# Processing Record 3 of Set 4 | north bend
# Processing Record 4 of Set 4 | sola
# Processing Record 5 of Set 4 | okhotsk
# Processing Record 6 of Set 4 | oulainen
# Processing Record 7 of Set 4 | yarensk
# Processing Record 8 of Set 4 | esperance
# Processing Record 9 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | severnyy
# Processing Record 12 of Set 4 | upernavik
# Processing Record 13 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 4 | kauhajoki
# Processing Record 15 of Set 4 | faanui
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | burica
# City not found. Skipping...
# Processing Record 18 of Set 4 | asau
# Processing Record 19 of Set 4 | hambantota
# Processing Record 20 of Set 4 | khatanga
# Processing Record 21 of Set 4 | alta
# Processing Record 22 of Set 4 | chokurdakh
# Processing Record 23 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 4 | hithadhoo
# Processing Record 25 of Set 4 | bundaberg
# Processing Record 26 of Set 4 | sabha
# Processing Record 27 of Set 4 | berezniki
# Processing Record 28 of Set 4 | nanortalik
# Processing Record 29 of Set 4 | jalu
# Processing Record 30 of Set 4 | yeletskiy
# City not found. Skipping...
# Processing Record 31 of Set 4 | arica
# Processing Record 32 of Set 4 | antalaha
# Processing Record 33 of Set 4 | belmonte
# Processing Record 34 of Set 4 | olafsvik
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | mandalgovi
# Processing Record 37 of Set 4 | denpasar
# Processing Record 38 of Set 4 | san luis
# Processing Record 39 of Set 4 | halifax
# Processing Record 40 of Set 4 | pangai
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | gigmoto
# Processing Record 43 of Set 4 | zhigansk
# Processing Record 44 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 45 of Set 4 | castro
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | udachnyy
# Processing Record 49 of Set 4 | horsham
# Processing Record 50 of Set 4 | raudeberg
# Processing Record 1 of Set 5 | comodoro rivadavia
# Processing Record 2 of Set 5 | saint-leu
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | chepareria
# Processing Record 5 of Set 5 | dagana
# Processing Record 6 of Set 5 | bereznik
# Processing Record 7 of Set 5 | lexington park
# Processing Record 8 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 9 of Set 5 | neuquen
# Processing Record 10 of Set 5 | yuxia
# Processing Record 11 of Set 5 | taltal
# Processing Record 12 of Set 5 | dhidhdhoo
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | bongandanga
# Processing Record 15 of Set 5 | havoysund
# Processing Record 16 of Set 5 | pitimbu
# Processing Record 17 of Set 5 | wawa
# Processing Record 18 of Set 5 | vila franca do campo
# Processing Record 19 of Set 5 | manokwari
# Processing Record 20 of Set 5 | betioky
# Processing Record 21 of Set 5 | makat
# Processing Record 22 of Set 5 | new norfolk
# Processing Record 23 of Set 5 | keti bandar
# Processing Record 24 of Set 5 | waipawa
# Processing Record 25 of Set 5 | mamallapuram
# Processing Record 26 of Set 5 | airai
# Processing Record 27 of Set 5 | itoman
# Processing Record 28 of Set 5 | pozega
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | fort nelson
# Processing Record 31 of Set 5 | kostrzyn
# Processing Record 32 of Set 5 | sao paulo de olivenca
# Processing Record 33 of Set 5 | tuatapere
# Processing Record 34 of Set 5 | antofagasta
# Processing Record 35 of Set 5 | moju
# Processing Record 36 of Set 5 | norman wells
# Processing Record 37 of Set 5 | preobrazheniye
# Processing Record 38 of Set 5 | pangnirtung
# Processing Record 39 of Set 5 | makakilo city
# Processing Record 40 of Set 5 | aitape
# Processing Record 41 of Set 5 | kiama
# Processing Record 42 of Set 5 | peniche
# Processing Record 43 of Set 5 | ayna
# Processing Record 44 of Set 5 | kupang
# Processing Record 45 of Set 5 | krasnogorodsk
# Processing Record 46 of Set 5 | bantogon
# Processing Record 47 of Set 5 | barcelos
# Processing Record 48 of Set 5 | longyearbyen
# Processing Record 49 of Set 5 | pilar
# Processing Record 50 of Set 5 | vao
# Processing Record 1 of Set 6 | key west
# Processing Record 2 of Set 6 | severo-kurilsk
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | palembang
# Processing Record 5 of Set 6 | gamba
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | pangkalanbuun
# Processing Record 8 of Set 6 | lipin bor
# Processing Record 9 of Set 6 | chimbote
# Processing Record 10 of Set 6 | husavik
# Processing Record 11 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 12 of Set 6 | dawei
# Processing Record 13 of Set 6 | nouadhibou
# Processing Record 14 of Set 6 | craig
# Processing Record 15 of Set 6 | fourmies
# Processing Record 16 of Set 6 | bozoum
# Processing Record 17 of Set 6 | samana
# Processing Record 18 of Set 6 | khromtau
# Processing Record 19 of Set 6 | sulangan
# Processing Record 20 of Set 6 | irpa irpa
# Processing Record 21 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 6 | kailua
# Processing Record 23 of Set 6 | bogande
# Processing Record 24 of Set 6 | buraydah
# Processing Record 25 of Set 6 | montauban
# Processing Record 26 of Set 6 | harper
# Processing Record 27 of Set 6 | tanshui
# City not found. Skipping...
# Processing Record 28 of Set 6 | sinnamary
# Processing Record 29 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 30 of Set 6 | russell
# Processing Record 31 of Set 6 | chernyshevskiy
# Processing Record 32 of Set 6 | port elizabeth
# Processing Record 33 of Set 6 | mareeba
# Processing Record 34 of Set 6 | cabo san lucas
# Processing Record 35 of Set 6 | kazerun
# Processing Record 36 of Set 6 | seoul
# Processing Record 37 of Set 6 | belaya gora
# Processing Record 38 of Set 6 | isangel
# Processing Record 39 of Set 6 | walvis bay
# Processing Record 40 of Set 6 | misratah
# Processing Record 41 of Set 6 | salinopolis
# Processing Record 42 of Set 6 | khani
# Processing Record 43 of Set 6 | graham
# Processing Record 44 of Set 6 | arman
# Processing Record 45 of Set 6 | aykhal
# Processing Record 46 of Set 6 | klaksvik
# Processing Record 47 of Set 6 | maarianhamina
# Processing Record 48 of Set 6 | sanghar
# Processing Record 49 of Set 6 | sao paulo do potengi
# Processing Record 50 of Set 6 | a
# City not found. Skipping...
# Processing Record 1 of Set 7 | rio gallegos
# Processing Record 2 of Set 7 | nuevo progreso
# Processing Record 3 of Set 7 | kidal
# Processing Record 4 of Set 7 | caravelas
# Processing Record 5 of Set 7 | najran
# Processing Record 6 of Set 7 | fortuna
# Processing Record 7 of Set 7 | galesong
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | tessalit
# Processing Record 10 of Set 7 | campbell river
# Processing Record 11 of Set 7 | palu
# Processing Record 12 of Set 7 | bilma
# Processing Record 13 of Set 7 | guymon
# Processing Record 14 of Set 7 | eganville
# Processing Record 15 of Set 7 | saint-philippe
# Processing Record 16 of Set 7 | ulaangom
# Processing Record 17 of Set 7 | san ignacio
# Processing Record 18 of Set 7 | chuy
# Processing Record 19 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | deputatskiy
# Processing Record 22 of Set 7 | san roque
# Processing Record 23 of Set 7 | hirara
# Processing Record 24 of Set 7 | grindavik
# Processing Record 25 of Set 7 | goderich
# Processing Record 26 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 27 of Set 7 | amelia
# Processing Record 28 of Set 7 | krasnovishersk
# Processing Record 29 of Set 7 | valdivia
# Processing Record 30 of Set 7 | sitka
# Processing Record 31 of Set 7 | qasigiannguit
# Processing Record 32 of Set 7 | janesville
# Processing Record 33 of Set 7 | torbay
# Processing Record 34 of Set 7 | richards bay
# Processing Record 35 of Set 7 | emerald
# Processing Record 36 of Set 7 | tyubuk
# Processing Record 37 of Set 7 | sao filipe
# Processing Record 38 of Set 7 | mendi
# Processing Record 39 of Set 7 | tiznit
# Processing Record 40 of Set 7 | tiarei
# Processing Record 41 of Set 7 | ye
# City not found. Skipping...
# Processing Record 42 of Set 7 | srednekolymsk
# Processing Record 43 of Set 7 | port blair
# Processing Record 44 of Set 7 | vernon
# Processing Record 45 of Set 7 | east london
# Processing Record 46 of Set 7 | hobyo
# Processing Record 47 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 7 | bengkalis
# City not found. Skipping...
# Processing Record 49 of Set 7 | newport
# Processing Record 50 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 8 | narsaq
# Processing Record 2 of Set 8 | tarko-sale
# Processing Record 3 of Set 8 | alibagu
# City not found. Skipping...
# Processing Record 4 of Set 8 | sao joao de pirabas
# Processing Record 5 of Set 8 | wad rawah
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | faya
# Processing Record 8 of Set 8 | ixtapa
# Processing Record 9 of Set 8 | tekirdag
# Processing Record 10 of Set 8 | margate
# Processing Record 11 of Set 8 | vestmannaeyjar
# Processing Record 12 of Set 8 | mutoko
# Processing Record 13 of Set 8 | sibolga
# Processing Record 14 of Set 8 | sumbe
# Processing Record 15 of Set 8 | nanzhang
# Processing Record 16 of Set 8 | atar
# Processing Record 17 of Set 8 | xining
# Processing Record 18 of Set 8 | sattahip
# Processing Record 19 of Set 8 | ampanihy
# Processing Record 20 of Set 8 | inzer
# Processing Record 21 of Set 8 | sawang daen din
# Processing Record 22 of Set 8 | mosquera
# Processing Record 23 of Set 8 | kedougou
# Processing Record 24 of Set 8 | kazanskaya
# Processing Record 25 of Set 8 | gemunden
# Processing Record 26 of Set 8 | abu kamal
# Processing Record 27 of Set 8 | chippewa falls
# Processing Record 28 of Set 8 | gorontalo
# Processing Record 29 of Set 8 | nenjiang
# Processing Record 30 of Set 8 | zaragoza
# Processing Record 31 of Set 8 | leibnitz
# Processing Record 32 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 33 of Set 8 | biak
# Processing Record 34 of Set 8 | santa barbara
# Processing Record 35 of Set 8 | garowe
# Processing Record 36 of Set 8 | pisco
# Processing Record 37 of Set 8 | tautira
# Processing Record 38 of Set 8 | kassala
# Processing Record 39 of Set 8 | ambulu
# Processing Record 40 of Set 8 | ucluelet
# Processing Record 41 of Set 8 | vardo
# Processing Record 42 of Set 8 | kaitangata
# Processing Record 43 of Set 8 | poum
# Processing Record 44 of Set 8 | codrington
# Processing Record 45 of Set 8 | kirakira
# Processing Record 46 of Set 8 | raga
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | bowen
# Processing Record 49 of Set 8 | port lincoln
# Processing Record 50 of Set 8 | praia da vitoria
# Processing Record 1 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 2 of Set 9 | kerman
# Processing Record 3 of Set 9 | saint-pierre
# Processing Record 4 of Set 9 | mbuji-mayi
# Processing Record 5 of Set 9 | ust-nera
# Processing Record 6 of Set 9 | nanyang
# Processing Record 7 of Set 9 | san jose
# Processing Record 8 of Set 9 | umba
# Processing Record 9 of Set 9 | dolny kubin
# Processing Record 10 of Set 9 | pavlogradka
# Processing Record 11 of Set 9 | gladstone
# Processing Record 12 of Set 9 | gondar
# Processing Record 13 of Set 9 | voh
# Processing Record 14 of Set 9 | mayumba
# Processing Record 15 of Set 9 | charcas
# Processing Record 16 of Set 9 | semme
# Processing Record 17 of Set 9 | ossora
# Processing Record 18 of Set 9 | ambilobe
# Processing Record 19 of Set 9 | carutapera
# Processing Record 20 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 9 | dongsheng
# Processing Record 22 of Set 9 | vieste
# Processing Record 23 of Set 9 | shanhetun
# Processing Record 24 of Set 9 | vila do maio
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | nabire
# Processing Record 27 of Set 9 | lavrentiya
# Processing Record 28 of Set 9 | saldanha
# Processing Record 29 of Set 9 | alpena
# Processing Record 30 of Set 9 | makinsk
# Processing Record 31 of Set 9 | puerto escondido
# Processing Record 32 of Set 9 | nichinan
# Processing Record 33 of Set 9 | pacifica
# Processing Record 34 of Set 9 | menongue
# Processing Record 35 of Set 9 | pimenta bueno
# Processing Record 36 of Set 9 | vredendal
# Processing Record 37 of Set 9 | berlevag
# Processing Record 38 of Set 9 | tabarqah
# City not found. Skipping...
# Processing Record 39 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 40 of Set 9 | nome
# Processing Record 41 of Set 9 | hualmay
# Processing Record 42 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 9 | sechura
# Processing Record 44 of Set 9 | alofi
# Processing Record 45 of Set 9 | ranong
# Processing Record 46 of Set 9 | bhum
# Processing Record 47 of Set 9 | kanye
# Processing Record 48 of Set 9 | nusaybin
# Processing Record 49 of Set 9 | suntar
# Processing Record 50 of Set 9 | astoria
# Processing Record 1 of Set 10 | eenhana
# Processing Record 2 of Set 10 | mount pleasant
# Processing Record 3 of Set 10 | ciudad bolivar
# Processing Record 4 of Set 10 | thompson
# Processing Record 5 of Set 10 | yashkul
# Processing Record 6 of Set 10 | rosario
# Processing Record 7 of Set 10 | cockburn town
# Processing Record 8 of Set 10 | buin
# Processing Record 9 of Set 10 | banda aceh
# Processing Record 10 of Set 10 | hofn
# Processing Record 11 of Set 10 | flinders
# Processing Record 12 of Set 10 | rawson
# Processing Record 13 of Set 10 | naze
# Processing Record 14 of Set 10 | baruun-urt
# Processing Record 15 of Set 10 | sao gabriel da cachoeira
# Processing Record 16 of Set 10 | juneau
# Processing Record 17 of Set 10 | morrope
# Processing Record 18 of Set 10 | maxixe
# Processing Record 19 of Set 10 | wamba
# Processing Record 20 of Set 10 | coralville
# Processing Record 21 of Set 10 | banamba
# Processing Record 22 of Set 10 | namibe
# Processing Record 23 of Set 10 | businga
# Processing Record 24 of Set 10 | golaesti
# Processing Record 25 of Set 10 | ibb
# Processing Record 26 of Set 10 | ust-tsilma
# Processing Record 27 of Set 10 | puerto quijarro
# Processing Record 28 of Set 10 | ust-karsk
# Processing Record 29 of Set 10 | gushikawa
# Processing Record 30 of Set 10 | vestmanna
# Processing Record 31 of Set 10 | lazaro cardenas
# Processing Record 32 of Set 10 | kitami
# Processing Record 33 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 34 of Set 10 | moree
# Processing Record 35 of Set 10 | fierze
# City not found. Skipping...
# Processing Record 36 of Set 10 | brownsville
# Processing Record 37 of Set 10 | itatiaia
# Processing Record 38 of Set 10 | mopti
# Processing Record 39 of Set 10 | tukrah
# Processing Record 40 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 41 of Set 10 | axim
# Processing Record 42 of Set 10 | saint-andre-avellin
# Processing Record 43 of Set 10 | bindura
# Processing Record 44 of Set 10 | finschhafen
# Processing Record 45 of Set 10 | ocos
# Processing Record 46 of Set 10 | labuhan
# Processing Record 47 of Set 10 | san quintin
# Processing Record 48 of Set 10 | morondava
# Processing Record 49 of Set 10 | perth
# Processing Record 50 of Set 10 | zhengjiatun
# Processing Record 1 of Set 11 | darhan
# Processing Record 2 of Set 11 | iringa
# Processing Record 3 of Set 11 | dawlatabad
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | kalabo
# Processing Record 6 of Set 11 | broken hill
# Processing Record 7 of Set 11 | balykshi
# Processing Record 8 of Set 11 | vadso
# Processing Record 9 of Set 11 | saint-denis
# Processing Record 10 of Set 11 | wuxue
# Processing Record 11 of Set 11 | vozhega
# Processing Record 12 of Set 11 | riohacha
# Processing Record 13 of Set 11 | veraval
# Processing Record 14 of Set 11 | okandja
# City not found. Skipping...
# Processing Record 15 of Set 11 | sokoto
# Processing Record 16 of Set 11 | puerto carreno
# Processing Record 17 of Set 11 | mvomero
# Processing Record 18 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 11 | juba
# Processing Record 20 of Set 11 | provideniya
# Processing Record 21 of Set 11 | camocim
# Processing Record 22 of Set 11 | mount gambier
# Processing Record 23 of Set 11 | marshfield
# Processing Record 24 of Set 11 | kieta
# Processing Record 25 of Set 11 | iqaluit
# Processing Record 26 of Set 11 | rudbar
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | opuwo
# Processing Record 29 of Set 11 | dejen
# Processing Record 30 of Set 11 | monte aprazivel
# Processing Record 31 of Set 11 | nagato
# Processing Record 32 of Set 11 | boca do acre
# Processing Record 33 of Set 11 | ponta delgada
# Processing Record 34 of Set 11 | westport
# Processing Record 35 of Set 11 | seymchan
# Processing Record 36 of Set 11 | whyalla
# Processing Record 37 of Set 11 | saurimo
# Processing Record 38 of Set 11 | zakopane
# Processing Record 39 of Set 11 | yar-sale
# Processing Record 40 of Set 11 | mitchell
# Processing Record 41 of Set 11 | tabou
# Processing Record 42 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 11 | shelburne
# Processing Record 44 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 11 | mumford
# Processing Record 46 of Set 11 | tondano
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | mayo
# Processing Record 49 of Set 11 | veseloyarsk
# Processing Record 50 of Set 11 | touros
# Processing Record 1 of Set 12 | shelopugino
# Processing Record 2 of Set 12 | ciras
# City not found. Skipping...
# Processing Record 3 of Set 12 | kalmunai
# Processing Record 4 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 12 | damghan
# Processing Record 6 of Set 12 | nunoa
# Processing Record 7 of Set 12 | the valley
# Processing Record 8 of Set 12 | batagay
# Processing Record 9 of Set 12 | jaen
# Processing Record 10 of Set 12 | guarapari
# Processing Record 11 of Set 12 | kahului
# Processing Record 12 of Set 12 | almaznyy
# Processing Record 13 of Set 12 | hearst
# Processing Record 14 of Set 12 | ancud
# Processing Record 15 of Set 12 | melfort
# Processing Record 16 of Set 12 | pudozh
# Processing Record 17 of Set 12 | rhyl
# Processing Record 18 of Set 12 | coari
# Processing Record 19 of Set 12 | zeya
# Processing Record 20 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 12 | khandbari
# Processing Record 22 of Set 12 | letlhakeng
# Processing Record 23 of Set 12 | gambiran
# Processing Record 24 of Set 12 | mackay
# Processing Record 25 of Set 12 | solnechnyy
# Processing Record 26 of Set 12 | vuktyl
# Processing Record 27 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 12 | ponnani
# Processing Record 29 of Set 12 | lucapa
# Processing Record 30 of Set 12 | lufilufi
# Processing Record 31 of Set 12 | lakes entrance
# Processing Record 32 of Set 12 | tolmachevo
# Processing Record 33 of Set 12 | lencois paulista
# Processing Record 34 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 12 | kabala
# Processing Record 36 of Set 12 | anchorage
# Processing Record 37 of Set 12 | nara
# Processing Record 38 of Set 12 | we
# City not found. Skipping...
# Processing Record 39 of Set 12 | conil
# Processing Record 40 of Set 12 | bull savanna
# Processing Record 41 of Set 12 | lar
# Processing Record 42 of Set 12 | guajara-mirim
# City not found. Skipping...
# Processing Record 43 of Set 12 | yuanping
# Processing Record 44 of Set 12 | jumla
# Processing Record 45 of Set 12 | bondo
# Processing Record 46 of Set 12 | oussouye
# Processing Record 47 of Set 12 | bonthe
# Processing Record 48 of Set 12 | lieksa
# Processing Record 49 of Set 12 | fruitvale
# Processing Record 50 of Set 12 | mandera
# Processing Record 1 of Set 13 | yamoussoukro
# Processing Record 2 of Set 13 | moose factory
# Processing Record 3 of Set 13 | irgakly
# Processing Record 4 of Set 13 | kysyl-syr
# Processing Record 5 of Set 13 | puerto penasco
# Processing Record 6 of Set 13 | cairns
# Processing Record 7 of Set 13 | were ilu
# Processing Record 8 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 13 | komsomolskiy
# Processing Record 10 of Set 13 | jonesboro
# Processing Record 11 of Set 13 | cape coast
# Processing Record 12 of Set 13 | garm
# City not found. Skipping...
# Processing Record 13 of Set 13 | tromso
# Processing Record 14 of Set 13 | basoko
# Processing Record 15 of Set 13 | rosario do sul
# Processing Record 16 of Set 13 | velika gorica
# Processing Record 17 of Set 13 | suksun
# Processing Record 18 of Set 13 | teberda
# Processing Record 19 of Set 13 | port hardy
# Processing Record 20 of Set 13 | colares
# Processing Record 21 of Set 13 | baghmara
# Processing Record 22 of Set 13 | rumoi
# Processing Record 23 of Set 13 | vitimskiy
# City not found. Skipping...
# Processing Record 24 of Set 13 | alvorada
# Processing Record 25 of Set 13 | shizuishan
# Processing Record 26 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 13 | half moon bay
# Processing Record 28 of Set 13 | ilo
# Processing Record 29 of Set 13 | vagay
# Processing Record 30 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 31 of Set 13 | bilokurakyne
# Processing Record 32 of Set 13 | palmer
# Processing Record 33 of Set 13 | caninde de sao francisco
# Processing Record 34 of Set 13 | phumi samraong
# City not found. Skipping...
# Processing Record 35 of Set 13 | gizycko
# Processing Record 36 of Set 13 | ozinki
# Processing Record 37 of Set 13 | sigli
# Processing Record 38 of Set 13 | santa maria
# Processing Record 39 of Set 13 | nurobod
# Processing Record 40 of Set 13 | nong bua
# Processing Record 41 of Set 13 | yarada
# Processing Record 42 of Set 13 | mapastepec
# Processing Record 43 of Set 13 | jaguaquara
# Processing Record 44 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 13 | pyapon
# Processing Record 47 of Set 13 | geraldton
# Processing Record 48 of Set 13 | gazanjyk
# Processing Record 49 of Set 13 | santa isabel do rio negro
# Processing Record 50 of Set 13 | lasa
# Processing Record 1 of Set 14 | alta floresta
# Processing Record 2 of Set 14 | saint-louis
# Processing Record 3 of Set 14 | quatre cocos
# Processing Record 4 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 14 | amiens
# Processing Record 6 of Set 14 | plettenberg bay
# Processing Record 7 of Set 14 | orlik
# Processing Record 8 of Set 14 | port augusta
# Processing Record 9 of Set 14 | saint-agapit
# Processing Record 10 of Set 14 | merauke
# Processing Record 11 of Set 14 | idrinskoye
# Processing Record 12 of Set 14 | iberia
# Processing Record 13 of Set 14 | villa carlos paz
# Processing Record 14 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 14 | durango
# Processing Record 16 of Set 14 | zhangye
# Processing Record 17 of Set 14 | henties bay
# Processing Record 18 of Set 14 | beira
# Processing Record 19 of Set 14 | marzuq
# Processing Record 20 of Set 14 | quelimane
# Processing Record 21 of Set 14 | mana
# Processing Record 22 of Set 14 | kodinsk
# Processing Record 23 of Set 14 | gizo
# Processing Record 24 of Set 14 | nagua
# Processing Record 25 of Set 14 | zyryanka
# Processing Record 26 of Set 14 | oksfjord
# Processing Record 27 of Set 14 | texarkana
# Processing Record 28 of Set 14 | eydhafushi
# Processing Record 29 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 14 | shubarkuduk
# Processing Record 31 of Set 14 | agadez
# Processing Record 32 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 14 | wanning
# Processing Record 34 of Set 14 | petatlan
# Processing Record 35 of Set 14 | concarneau
# Processing Record 36 of Set 14 | dicabisagan
# Processing Record 37 of Set 14 | gidole
# Processing Record 38 of Set 14 | selkirk
# Processing Record 39 of Set 14 | yerbogachen
# Processing Record 40 of Set 14 | chara
# Processing Record 41 of Set 14 | sorland
# Processing Record 42 of Set 14 | portland
# Processing Record 43 of Set 14 | sauda
# Processing Record 44 of Set 14 | barra da estiva
# Processing Record 45 of Set 14 | rorvik
# Processing Record 46 of Set 14 | maceio
# Processing Record 47 of Set 14 | innisfail
# Processing Record 48 of Set 14 | cap-aux-meules
# Processing Record 49 of Set 14 | stillwater
# Processing Record 50 of Set 14 | beringovskiy
# Processing Record 1 of Set 15 | maryville
# Processing Record 2 of Set 15 | bismarck
# Processing Record 3 of Set 15 | krasnoselkup
# Processing Record 4 of Set 15 | xiaoshi
# Processing Record 5 of Set 15 | tucupita
# Processing Record 6 of Set 15 | sartell
# Processing Record 7 of Set 15 | kuusamo
# Processing Record 8 of Set 15 | anniston
# Processing Record 9 of Set 15 | goundam
# Processing Record 10 of Set 15 | villarrica
# Processing Record 11 of Set 15 | altay
# Processing Record 12 of Set 15 | northam
# Processing Record 13 of Set 15 | kulhudhuffushi
# Processing Record 14 of Set 15 | santa marta
# Processing Record 15 of Set 15 | wewak
# Processing Record 16 of Set 15 | kenai
# Processing Record 17 of Set 15 | sosnovskiy
# City not found. Skipping...
# Processing Record 18 of Set 15 | wuhan
# Processing Record 19 of Set 15 | norrkoping
# Processing Record 20 of Set 15 | whitehorse
# Processing Record 21 of Set 15 | granadilla de abona
# Processing Record 22 of Set 15 | garbolovo
# Processing Record 23 of Set 15 | tremelo
# Processing Record 24 of Set 15 | broome
# Processing Record 25 of Set 15 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 26 of Set 15 | puurmani
# Processing Record 27 of Set 15 | andoain
# Processing Record 28 of Set 15 | oktyabrskoye
# Processing Record 29 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 15 | abeche
# Processing Record 31 of Set 15 | tual
# Processing Record 32 of Set 15 | gat
# Processing Record 33 of Set 15 | lapua
# Processing Record 34 of Set 15 | payo
# Processing Record 35 of Set 15 | adrar
# Processing Record 36 of Set 15 | maragogi
# Processing Record 37 of Set 15 | tarakan
# Processing Record 38 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 15 | zomin
# Processing Record 40 of Set 15 | yulara
# Processing Record 41 of Set 15 | salistea de sus
# Processing Record 42 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 43 of Set 15 | tabora
# Processing Record 44 of Set 15 | hay river
# Processing Record 45 of Set 15 | damavand
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0        Nago  26.5881  127.9761     overcast clouds     77.45        90
# 1     Awjilah  29.1081   21.2869           clear sky     97.70        13
# 2     Segezha  63.7415   34.3222     overcast clouds     45.19        79
# 3      Barrow  71.2906 -156.7887     overcast clouds     30.22        80
# 4      Kodiak  57.7900 -152.4072     overcast clouds     47.71        87
# 5       Bluff -46.6000  168.3333          light rain     49.80        74
# 6  Georgetown   5.4112  100.3354          few clouds     81.90        87
# 7       Vaini -21.2000 -175.2000       broken clouds     64.56       100
# 8     Ushuaia -54.8000  -68.3000       broken clouds     33.46        93
# 9      Hobart -42.8794  147.3294     overcast clouds     48.06        73
#
#    Cloudiness  Wind Speed Country                 Date
# 0         100        8.72      JP  2021-05-28 17:15:15
# 1           1       10.09      LY  2021-05-28 17:15:16
# 2          93        5.95      RU  2021-05-28 17:15:16
# 3          90        8.05      US  2021-05-28 17:15:16
# 4          90        4.61      US  2021-05-28 17:15:17
# 5         100       14.14      NZ  2021-05-28 17:15:17
# 6          20        1.34      MY  2021-05-28 17:15:10
# 7          75        2.30      TO  2021-05-28 17:15:17
# 8          75       27.63      AR  2021-05-28 17:15:18
# 9          90        1.01      AU  2021-05-28 17:15:18

# %%
city_data_df.keys()
# Out:
# Index(['City', 'Lat', 'Lng', 'Current Description', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Current Description","Max Temp","Humidity","Cloudiness","Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country                 Date      Lat       Lng  \
# 0        Nago      JP  2021-05-28 17:15:15  26.5881  127.9761
# 1     Awjilah      LY  2021-05-28 17:15:16  29.1081   21.2869
# 2     Segezha      RU  2021-05-28 17:15:16  63.7415   34.3222
# 3      Barrow      US  2021-05-28 17:15:16  71.2906 -156.7887
# 4      Kodiak      US  2021-05-28 17:15:17  57.7900 -152.4072
# 5       Bluff      NZ  2021-05-28 17:15:17 -46.6000  168.3333
# 6  Georgetown      MY  2021-05-28 17:15:10   5.4112  100.3354
# 7       Vaini      TO  2021-05-28 17:15:17 -21.2000 -175.2000
# 8     Ushuaia      AR  2021-05-28 17:15:18 -54.8000  -68.3000
# 9      Hobart      AU  2021-05-28 17:15:18 -42.8794  147.3294
#
#   Current Description  Max Temp  Humidity  Cloudiness  Wind Speed
# 0     overcast clouds     77.45        90         100        8.72
# 1           clear sky     97.70        13           1       10.09
# 2     overcast clouds     45.19        79          93        5.95
# 3     overcast clouds     30.22        80          90        8.05
# 4     overcast clouds     47.71        87          90        4.61
# 5          light rain     49.80        74         100       14.14
# 6          few clouds     81.90        87          20        1.34
# 7       broken clouds     64.56       100          75        2.30
# 8       broken clouds     33.46        93          75       27.63
# 9     overcast clouds     48.06        73          90        1.01

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
